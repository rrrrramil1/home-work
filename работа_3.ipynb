# %% [markdown]
# <a href="https://colab.research.google.com/github/rrrrramil1/home-work/blob/main/%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![2025-04-02 13.32.16.jpg](data:image/jpeg;base64,...)
