# %% [markdown]
# <a href="https://colab.research.google.com/github/rrrrramil1/home-work/blob/main/%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок экрана 2025-03-21 в 14.37.10.png](data:image/png;base64,...)

# %%
import math

def f(x):
    if x > 0:
        return math.exp(math.exp(x)) - math.sin(x)
    elif x == 0:
        return math.exp(math.exp(x)) - math.pi
    else:
        return math.pi * math.cos(x)

# Ввод значения x от пользователя
x = float(input("Введите значение x: "))

# Вычисление и вывод результата
result = f(x)
print(f"f({x}) = {result}")
# Out:
# Введите значение x: 2
# f(2.0) = 1617.268694485828

# %%
def product_of_two_smallest(a, b, c):
    # Сортируем три числа по возрастанию
    numbers = sorted([a, b, c])
    # Возвращаем произведение двух наименьших
    return numbers[0] * numbers[1]

def main():
    # Ввод трех различных чисел
    a = float(input("Введите первое число: "))
    b = float(input("Введите второе число: "))
    c = float(input("Введите третье число: "))

    # Проверка, что числа различны
    if a == b or b == c or a == c:
        print("Ошибка: все числа должны быть различными.")
        return

    # Вычисление произведения двух наименьших чисел
    result = product_of_two_smallest(a, b, c)
    print(f"Произведение двух наименьших чисел: {result}")

# Запуск программы
main()
# Out:
# Введите первое число: 5
# Введите второе число: 3
# Введите третье число: 4
# Произведение двух наименьших чисел: 12.0

# %%
def is_leap_year(year):
    # Проверка на високосный год
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return True
    else:
        return False

def days_in_year(year):
    if is_leap_year(year):
        return 366
    else:
        return 365

def main():
    # Ввод года от пользователя
    year = int(input("Введите год (положительное целое число): "))

    # Проверка, что год положительный
    if year <= 0:
        print("Ошибка: год должен быть положительным числом.")
        return

    # Определение количества дней в году
    days = days_in_year(year)
    print(f"В {year} году {days} дней.")

# Запуск программы
main()
# Out:
# Введите год (положительное целое число): 2025
# В 2025 году 365 дней.

# %%
def is_divisor(a, b):
    # Проверяем, делится ли b на a без остатка
    return b % a == 0

def main():
    # Ввод двух чисел от пользователя
    a = int(input("Введите число a: "))
    b = int(input("Введите число b: "))

    # Проверка, является ли a делителем b
    if a == 0:
        print("Ошибка: число a не может быть равно 0.")
    else:
        if is_divisor(a, b):
            print(f"{a} является делителем {b}.")
        else:
            print(f"{a} не является делителем {b}.")

    # Проверка, является ли b делителем a
    if b == 0:
        print("Ошибка: число b не может быть равно 0.")
    else:
        if is_divisor(b, a):
            print(f"{b} является делителем {a}.")
        else:
            print(f"{b} не является делителем {a}.")

# Запуск программы
main()
# Out:
# Введите число a: 3
# Введите число b: 9
# 3 является делителем 9.
# 9 не является делителем 3.

# %%
def calculate_age(birth_year, birth_month, current_year, current_month):
    # Вычисляем разницу в годах и месяцах
    years = current_year - birth_year
    months = current_month - birth_month

    # Корректируем, если текущий месяц меньше месяца рождения
    if months < 0:
        years -= 1
        months += 12

    return years, months

def main():
    # Ввод данных о рождении
    birth_year = int(input("Введите год рождения: "))
    birth_month = int(input("Введите месяц рождения (1-12): "))

    # Ввод текущих данных
    current_year = int(input("Введите текущий год: "))
    current_month = int(input("Введите текущий месяц (1-12): "))

    # Проверка корректности ввода
    if birth_month < 1 or birth_month > 12 or current_month < 1 or current_month > 12:
        print("Ошибка: месяц должен быть в диапазоне от 1 до 12.")
        return
    if birth_year > current_year or (birth_year == current_year and birth_month > current_month):
        print("Ошибка: дата рождения не может быть позже текущей даты.")
        return

    # Вычисление возраста
    age_years, age_months = calculate_age(birth_year, birth_month, current_year, current_month)

    # Вывод результата
    print(f"Возраст: {age_years} полных лет и {age_months} полных месяцев.")

# Запуск программы
main()
# Out:
# Введите год рождения: 2001
# Введите месяц рождения (1-12): 03
# Введите текущий год: 2025
# Введите текущий месяц (1-12): 03
# Возраст: 24 полных лет и 0 полных месяцев.
