# %% [markdown]
# <a href="https://colab.research.google.com/github/rrrrramil1/home-work/blob/main/30_zadach_na_6_blokov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок экрана 2025-04-04 в 15.15.01.png](data:image/png;base64,...)

# %%
A = float(input("Введите A: "))
B = float(input("Введите B: "))

# Меняем местами
A, B = B, A

print("Новые значения:")
print("A =", A)
print("B =", B)
# Out:
# Введите A: 1
# Введите B: 2
# Новые значения:
# A = 2.0
# B = 1.0

# %%
A = float(input("Введите A: "))
B = float(input("Введите B: "))
C = float(input("Введите C: "))

# Сохраняем оригинальные значения
temp_A = A
temp_B = B
temp_C = C

# Выполняем сдвиг
A = temp_C
B = temp_A
C = temp_B

print("Новые значения:")
print("A =", A)
print("B =", B)
print("C =", C)
# Out:
# Введите A: 1
# Введите B: 2
# Введите C: 3
# Новые значения:
# A = 3.0
# B = 1.0
# C = 2.0

# %%
A = float(input("Введите A: "))
B = float(input("Введите B: "))
C = float(input("Введите C: "))

# Сохраняем оригинальные значения
temp_A = A
temp_B = B
temp_C = C

# Выполняем сдвиг
A = temp_B
B = temp_C
C = temp_A

print("Новые значения:")
print("A =", A)
print("B =", B)
print("C =", C)
# Out:
# Введите A: 1
# Введите B: 2
# Введите C: 3
# Новые значения:
# A = 2.0
# B = 3.0
# C = 1.0

# %%
x = float(input("Введите x: "))
y = 3 * x**6 - 6 * x**2 - 7
print("y =", y)
# Out:
# Введите x: 1
# y = -10.0

# %%
x = float(input("Введите x: "))
temp = x - 3
y = 4 * temp**6 - 7 * temp**3 + 2
print("y =", y)
# Out:
# Введите x: 1
# y = 314.0

# %%
A = float(input("Введите A: "))
A_squared = A * A       # A²
A_4 = A_squared * A_squared  # A⁴
A_8 = A_4 * A_4         # A⁸

print("A² =", A_squared)
print("A⁴ =", A_4)
print("A⁸ =", A_8)
# Out:
# Введите A: 2
# A² = 4.0
# A⁴ = 16.0
# A⁸ = 256.0

# %% [markdown]
# ![Снимок экрана 2025-04-04 в 15.21.16.png](data:image/png;base64,...)

# %%
A = int(input("Введите A (A > B): "))
B = int(input("Введите B: "))

remainder = A % B
print("Длина незанятой части:", remainder)
# Out:
# Введите A (A > B): 10
# Введите B: 3
# Длина незанятой части: 1

# %%
number = int(input("Введите двузначное число: "))

tens = number // 10
units = number % 10

print("Десятки:", tens)
print("Единицы:", units)
# Out:
# Введите двузначное число: 25
# Десятки: 2
# Единицы: 5

# %%
number = int(input("Введите двузначное число: "))

tens = number // 10
units = number % 10

sum_digits = tens + units
product = tens * units

print("Сумма цифр:", sum_digits)
print("Произведение цифр:", product)
# Out:
# Введите двузначное число: 25
# Сумма цифр: 7
# Произведение цифр: 10

# %%
number = int(input("Введите двузначное число: "))

tens = number // 10
units = number % 10

swapped = units * 10 + tens
print("Число после перестановки:", swapped)
# Out:
# Введите двузначное число: 23
# Число после перестановки: 32

# %%
number = int(input("Введите трехзначное число: "))

hundreds = number // 100
print("Первая цифра (сотни):", hundreds)
# Out:
# Введите трехзначное число: 423
# Первая цифра (сотни): 4

# %% [markdown]
# ![Снимок экрана 2025-04-04 в 15.30.45.png](data:image/png;base64,...)

# %%
num = int(input("Введите трехзначное число: "))
a = num // 100
b = (num // 10) % 10
c = num % 10

is_increasing = a < b < c
is_decreasing = a > b > c

print("Цифры образуют возрастающую или убывающую последовательность:",
      is_increasing or is_decreasing)
# Out:
# Введите трехзначное число: 123
# Цифры образуют возрастающую или убывающую последовательность: True

# %%
num = input("Введите четырехзначное число: ")

if len(num) != 4 or not num.isdigit():
    print("Ошибка: нужно ввести ровно 4 цифры")
else:
    is_palindrome = num == num[::-1]
    print("Число является палиндромом:", is_palindrome)
# Out:
# Введите четырехзначное число: 1221
# Число является палиндромом: True

# %%
A = float(input("Введите A (не 0): "))
B = float(input("Введите B: "))
C = float(input("Введите C: "))

D = B**2 - 4*A*C
has_real_roots = D >= 0

print("Уравнение имеет вещественные корни:", has_real_roots)
# Out:
# Введите A (не 0): 1
# Введите B: 66
# Введите C: 2
# Уравнение имеет вещественные корни: True

# %%
x = float(input("Введите x: "))
y = float(input("Введите y: "))

in_second_quadrant = x < 0 and y > 0
print("Точка во второй четверти:", in_second_quadrant)
# Out:
# Введите x: -1
# Введите y: 1
# Точка во второй четверти: True

# %%
x = float(input("Введите x: "))
y = float(input("Введите y: "))

in_fourth_quadrant = x > 0 and y < 0
print("Точка в четвертой четверти:", in_fourth_quadrant)
# Out:
# Введите x: 1
# Введите y: -1
# Точка в четвертой четверти: True

# %% [markdown]
# ![Снимок экрана 2025-04-04 в 15.40.32.png](data:image/png;base64,...)

# %%
x = int(input("Введите координату x: "))
y = int(input("Введите координату y: "))

if x == 0 and y == 0:
    print(0)
elif y == 0:
    print(1)  # На оси OX
elif x == 0:
    print(2)  # На оси OY
else:
    print(3)  # Не на осях
# Out:
# Введите координату x: 1
# Введите координату y: 1
# 3

# %%
x = float(input("Введите x (не 0): "))
y = float(input("Введите y (не 0): "))

if x > 0 and y > 0:
    print(1)  # Первая четверть
elif x < 0 and y > 0:
    print(2)  # Вторая четверть
elif x < 0 and y < 0:
    print(3)  # Третья четверть
else:
    print(4)  # Четвертая четверть
# Out:
# Введите x (не 0): -1
# Введите y (не 0): -1
# 3

# %%
print("Введите координаты трех вершин (x y):")
x1, y1 = map(int, input("Вершина 1: ").split())
x2, y2 = map(int, input("Вершина 2: ").split())
x3, y3 = map(int, input("Вершина 3: ").split())

# Находим недостающие координаты
if x1 == x2:
    x4 = x3
elif x1 == x3:
    x4 = x2
else:
    x4 = x1

if y1 == y2:
    y4 = y3
elif y1 == y3:
    y4 = y2
else:
    y4 = y1

print(f"Координаты четвертой вершины: ({x4}, {y4})")
# Out:
# Введите координаты трех вершин (x y):
# Вершина 1: 5 5
# Вершина 2: 6 6
# Вершина 3: 5 6
# Координаты четвертой вершины: (6, 5)

# %%
import math

x = float(input("Введите x: "))

if x > 0:
    f = 2 * math.sin(x)
else:
    f = 6 - x

print(f"f({x}) = {f:.3f}")
# Out:
# Введите x: 2
# f(2.0) = 1.819

# %%
x = int(input("Введите целое x: "))

if x < -2 or x > 2:
    f = 2 * x
else:
    f = -3 * x

print(f"f({x}) = {f}")
# Out:
# Введите целое x: 3
# f(3) = 6

# %% [markdown]
# ![Снимок экрана 2025-04-04 в 15.48.00.png](data:image/png;base64,...)

# %%
N = int(input("Введите N (>1): "))
if N <= 1:
    print("Ошибка: N должно быть >1")
else:
    A = [0] * N
    A[0], A[1] = 1.0, 2.0
    for K in range(2, N):
        A[K] = (A[K-2] + 2 * A[K-1]) / 3
    print("Последовательность:", [round(x, 4) for x in A])
# Out:
# Введите N (>1): 2
# Последовательность: [1.0, 2.0]

# %%
N = int(input("Введите N (>2): "))
if N <= 2:
    print("Ошибка: N должно быть >2")
else:
    A = [0] * N
    A[0], A[1], A[2] = 1, 2, 3
    for K in range(3, N):
        A[K] = A[K-1] + A[K-2] - 2 * A[K-3]
    print("Последовательность:", A)
# Out:
# Введите N (>2): 4
# Последовательность: [1, 2, 3, 3]

# %%
N = int(input("Введите N: "))
K = int(input("Введите K: "))
sum_result = 0.0
for i in range(1, N+1):
    sum_result += i ** K
print(f"Сумма: {sum_result:.2f}")
# Out:
# Введите N: 4
# Введите K: 2
# Сумма: 30.00

# %%
N = int(input("Введите N (>0): "))
sum_result = 0.0
for i in range(1, N+1):
    sum_result += i ** i
print(f"Сумма: {sum_result:.2f}")
# Out:
# Введите N (>0): 3
# Сумма: 32.00

# %%
N = int(input("Введите N (>0): "))
sum_result = 0.0
for i in range(1, N+1):
    exponent = N - i + 1
    sum_result += i ** exponent
print(f"Сумма: {sum_result:.2f}")
# Out:
# Введите N (>0): 3
# Сумма: 8.00

# %% [markdown]
# ![Снимок экрана 2025-04-04 в 15.52.32.png](data:image/png;base64,...)

# %%
N = int(input("Введите число N (>1): "))
if N <= 1:
    print("Ошибка: N должно быть >1")
else:
    is_prime = True
    for i in range(2, int(N**0.5) + 1):
        if N % i == 0:
            is_prime = False
            break
    print(is_prime)
# Out:
# Введите число N (>1): 7
# True

# %%
A = int(input("Введите A: "))
B = int(input("Введите B: "))

while B != 0:
    A, B = B, A % B
print("НОД:", A)
# Out:
# Введите A: 2
# Введите B: 4
# НОД: 2

# %%
N = int(input("Введите N (>1): "))
a, b = 1, 1
while b < N:
    a, b = b, a + b
print(b == N)
# Out:
# Введите N (>1): 5
# True

# %%
N = int(input("Введите N (>1): "))
a, b = 1, 1
while b <= N:
    a, b = b, a + b
print("Первое число Фибоначчи > N:", b)
# Out:
# Введите N (>1): 6
# Первое число Фибоначчи > N: 8

# %%
N = int(input("Введите число Фибоначчи N (>1): "))
a, b = 1, 1
while b < N:
    a, b = b, a + b

if b != N:
    print("Ошибка: N не является числом Фибоначчи")
else:
    # Находим F_{K-1} и F_{K+1}
    prev = a
    next_fib = a + b
    print(f"F_{{K-1}} = {prev}, F_{{K+1}} = {next_fib}")
# Out:
# Введите число Фибоначчи N (>1): 5
# F_{K-1} = 3, F_{K+1} = 8
